# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/loveysharma/Downloads/cars_ds_fina.csv')

# %%
# finding null values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Make                      0
# Model                     0
# Variant                   0
# Ex-Showroom_Price         0
# Displacement              0
# Cylinders                 0
# Valves_Per_Cylinder       0
# Drivetrain                0
# Cylinder_Configuration    0
# Emission_Norm             0
# Engine_Location           0
# Fuel_System               0
# Fuel_Tank_Capacity        0
# Fuel_Type                 0
# Height                    0
# Length                    0
# Width                     0
# Body_Type                 0
# Doors                     0
# dtype: int64

# %%
# Check what are the different type of make.What is the count of each make?

# %%
df['Make'].value_counts()
# Out:
# Maruti Suzuki    28
# Renault          16
# Datsun           15
# Tata             14
# Toyota           12
# Hyundai           8
# Premier           6
# Name: Make, dtype: int64

# %%
# Select all cars who has bodytype SUV or MUV

# %%
df[df['Body_Type'].isin(['SUV','MUV'])]
# Out:
#     Unnamed: 0     Make   Model Variant Ex-Showroom_Price Displacement  \
# 77          77  Renault  Triber     Rxe      Rs. 4,95,000       999 cc
# 78          78  Renault  Triber     Rxl      Rs. 5,59,000       999 cc
# 79          79  Renault  Triber     Rxt      Rs. 6,09,000       999 cc
# 80          80  Renault  Triber     Rxz      Rs. 6,63,000       999 cc
# 81          81  Premier     Rio      Gx      Rs. 5,06,000      1173 cc
# 82          82  Premier     Rio      Ex      Rs. 5,68,623      1489 cc
# 83          83  Premier     Rio     Glx      Rs. 6,70,000      1173 cc
# 84          84  Premier     Rio      Dx      Rs. 6,03,000      1489 cc
# 85          85  Premier     Rio      Lx      Rs. 7,39,000      1489 cc
# 86          86  Premier     Rio   Crdi4      Rs. 7,39,000      1248 cc
#
#     Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 77          3                    4  FWD (Front Wheel Drive)
# 78          3                    4  FWD (Front Wheel Drive)
# ...

# %%
# Remove all cars who has cylinder less than 3

# %%
df[~(df['Cylinders']<3)]
# Out:
#     Unnamed: 0    Make       Model        Variant Ex-Showroom_Price  \
# 6            6  Datsun     Redi-Go              D      Rs. 2,79,650
# 7            7  Datsun     Redi-Go              T      Rs. 3,51,832
# 8            8  Datsun     Redi-Go              A      Rs. 3,33,419
# 9            9  Datsun     Redi-Go              S      Rs. 3,62,000
# 10          10  Datsun     Redi-Go          1.0 S      Rs. 3,90,000
# ..         ...     ...         ...            ...               ...
# 94          94  Toyota  Etios Liva   Dual Tone Vd      Rs. 7,20,700
# 95          95  Toyota  Etios Liva   Dual Tone Vx      Rs. 6,41,700
# 96          96  Toyota  Etios Liva  Dual Tone Vxd      Rs. 7,56,700
# 97          97  Toyota  Etios Liva             Gx      Rs. 5,58,400
# 98          98  Toyota  Etios Liva            Gxd      Rs. 6,86,000
#
#    Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 6        799 cc          3                    4  FWD (Front Wheel Drive)
# ...

# %%
# Increase the value of fuel tank capacity by 3

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0          2                    2  RWD (Rear Wheel Drive)
# 1          2                    2  RWD (Rear Wheel Drive)
# 2          2                    2  RWD (Rear Wheel Drive)
# 3          2                    2  RWD (Rear Wheel Drive)
# 4          2                    2  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration Emission_Norm   Engine_Location Fuel_System  \
# 0                In-line         BS IV  Rear, Transverse   Injection
# ...

# %%
df['Valves_Per_Cylinder']=df['Valves_Per_Cylinder'].apply(lambda x:x+3)

# %%
df
# Out:
#     Unnamed: 0    Make       Model        Variant Ex-Showroom_Price  \
# 0            0    Tata   Nano Genx             Xt      Rs. 2,92,667
# 1            1    Tata   Nano Genx             Xe      Rs. 2,36,447
# 2            2    Tata   Nano Genx        Emax Xm      Rs. 2,96,661
# 3            3    Tata   Nano Genx            Xta      Rs. 3,34,768
# 4            4    Tata   Nano Genx             Xm      Rs. 2,72,223
# ..         ...     ...         ...            ...               ...
# 94          94  Toyota  Etios Liva   Dual Tone Vd      Rs. 7,20,700
# 95          95  Toyota  Etios Liva   Dual Tone Vx      Rs. 6,41,700
# 96          96  Toyota  Etios Liva  Dual Tone Vxd      Rs. 7,56,700
# 97          97  Toyota  Etios Liva             Gx      Rs. 5,58,400
# 98          98  Toyota  Etios Liva            Gxd      Rs. 6,86,000
#
#    Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 0        624 cc          2                    5   RWD (Rear Wheel Drive)
# ...
